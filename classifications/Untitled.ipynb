# %% [markdown]
# # Kernel SVM for nonlinear boundary
# ## 1. Test of kernel trick
# Kernels adds nonlinearity so linearly nonseparable boundary can be drawn

# %%
import numpy as np
import matplotlib.pyplot as plt
# svm
from sklearn.svm import SVC
# separating training/testing
from sklearn.model_selection import train_test_split as tts
xxor = np.random.randn(350,2)
yxor = np.logical_xor(xxor[:,0]>0, xxor[:,1]>0)
# see what the scatter is
plt.scatter (xxor[yxor==True,0],xxor[yxor==True,1],
             marker='+',c='r')
plt.scatter (xxor[yxor==False,0],xxor[yxor==False,1],
             marker='o',c='b')
plt.show()

# %%
svc = SVC(C=100.0, kernel='rbf')
xtrain,xtest,ytrain,ytest=tts(xxor,yxor,test_size=0.3)
xx,yy=np.meshgrid(np.linspace(xxor[]))
